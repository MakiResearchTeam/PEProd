# %%
from petools.gpu import PosePredictor

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
pose_predictor = PosePredictor(
    path_to_pb='model/model.pb',
    path_to_config='model/config.json',
    gpu_id=2
)
# Out:
# WARNING:tensorflow:From /home/ikilbas/anaconda3/lib/python3.7/site-packages/petools/gpu/utils.py:108: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /home/ikilbas/anaconda3/lib/python3.7/site-packages/petools/gpu/utils.py:109: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /home/ikilbas/anaconda3/lib/python3.7/site-packages/petools/gpu/pose_predictor_pb.py:80: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/ikilbas/anaconda3/lib/python3.7/site-packages/petools/gpu/pose_predictor_pb.py:94: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %% [markdown]
# ## Try to predict

# %%
img_path = '/mnt/data/labeling_service/left_del_2020-10-03 11-47-00/images/1126.png'

# %%
single_img = cv2.imread(img_path)

# %%
plt.imshow(single_img)

# %%
predictions = pose_predictor.predict(single_img)

# %%
predictions
# Out:
# {'humans': [{0: [253.52113342285156, 546.75, 0.8029809594154358],
#    1: [256.9013977050781, 469.125, 0.8342688679695129],
#    2: [256.9013977050781, 442.125, 0.8468365669250488],
#    3: [251.8309783935547, 394.875, 0.7967987060546875],
#    4: [310.98590087890625, 469.125, 0.8336068391799927],
#    5: [202.81689453125, 469.125, 0.8349308967590332],
#    6: [398.87322998046875, 486.0, 0.841830313205719],
#    7: [118.30986022949219, 496.125, 0.8442908525466919],
#    8: [500.28167724609375, 482.625, 0.8262227773666382],
#    9: [37.18309783935547, 496.125, 0.725501298904419],
#    10: [294.0845031738281, 661.5, 0.8151177167892456],
#    11: [219.7183074951172, 668.25, 0.8390918374061584],
#    12: [300.8450622558594, 816.75, 0.8364037275314331],
#    13: [226.47886657714844, 820.125, 0.8374191522598267],
#    14: [307.6056213378906, 941.625, 0.840610682964325],
#    15: [236.61972045898438, 938.25, 0.8355903625488281],
#    16: [314.3662109375, 992.25, 0.8401154279708862],
#    17: [229.85916137695312, 992.25, 0.8474811911582947],
#    18: [537.4647827148438, 472.5, 0.7365536093711853],
#    19: [561.1267700195312, 475.875, 0.7661545276641846],
#    20: [0.0, 0.0, 0.0],
#    21: [0.0, 0.0, 0.0],
#    22: [256.9013977050781, 664.875, 0.8271048069000244]}],
#  'time': 3.6478729248046875}

# %%
plt.imshow(pose_predictor.draw(single_img, predictions))

# %% [markdown]
# ## Measure speed

# %%
import time

start = time.time()

n = 50
for _ in range(n):
    _ = pose_predictor.predict(single_img)
print('fps: ', n / (time.time() - start))
# Out:
# fps:  47.68615009884438
